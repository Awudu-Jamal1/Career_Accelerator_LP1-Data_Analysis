# %%
import pandas as pd
import numpy as np
import os
import glob

# %%
cwd = os.path.abspath('')
file_list = os.listdir(cwd)
file_list
# Out:
# ['.git',
#  '.vscode',
#  'India Startup Funding.zip',
#  'README.md',
#  'startup_funding2018.csv',
#  'startup_funding2019.csv',
#  'startup_funding2020.csv',
#  'startup_funding2021.csv',
#  'Untitled-1.ipynb']

# %%
csv_files = glob.glob('*.{}'.format('csv'))
csv_files
# Out:
# ['startup_funding2018.csv',
#  'startup_funding2019.csv',
#  'startup_funding2020.csv',
#  'startup_funding2021.csv']

# %%
df_concat=pd.concat([pd.read_csv(f) for f in csv_files],ignore_index=True)

df_concat
# Out:
#          Company Name                                           Industry  \
# 0     TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1     Happy Cow Dairy                               Agriculture, Farming
# 2          MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3         PayMe India                        Financial Services, FinTech
# 4            Eunimart                 E-Commerce Platforms, Retail, SaaS
# ...               ...                                                ...
# 2874              NaN                                                NaN
# 2875              NaN                                                NaN
# 2876              NaN                                                NaN
# 2877              NaN                                                NaN
# 2878              NaN                                                NaN
#
#      Round/Series       Amount                          Location  \
# ...

# %%
df =pd.read_csv( csv_files[1])

# %%
df_0=pd.read_csv( csv_files[0])
df_1=pd.read_csv( csv_files[1])
df_2=pd.read_csv( csv_files[2])
dfs_3=pd.read_csv( csv_files[3])

# %%
df_0.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# ...

# %%
df_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
# dtypes: object(6)
# memory usage: 24.8+ KB

# %%
df_0['Amount'] =df_0['Amount'].str.replace('₹','')
df_0['Amount'] =df_0['Amount'].str.replace(',','')
# df_0['Amount'] =df_0['Amount'].str.replace('null',' null')

# df_0['Usd'] =df_0['Amount']/64

# %%
df_0.isnull().sum()
# Out:
# Company Name     0
# Industry         0
# Round/Series     0
# Amount           0
# Location         0
# About Company    0
# dtype: int64

# %%
# df_0['Amount'] = df_0['Amount'].astype(str).astype(int)
df_0 = df_0[df_0['Amount'].apply(lambda x: str(x).isdigit())]

# %%
df_0['Amount'] = df_0['Amount'].astype(str).astype(float)

# %%
# df_0['Amount'] = df_0['Amount']//63.2965
df_0['Amount'] = df_0['Amount']//63.2965
df_0['Amount'] = df_0['Amount'].apply(int)

# %%
df_0["Amount"].head()
# Out:
# 0       3949
# 1     631946
# 2    1026913
# 3      31597
# 5      25277
# Name: Amount, dtype: int64

# %%
# df_0

# %%
df_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 319 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   319 non-null    object
#  1   Industry       319 non-null    object
#  2   Round/Series   319 non-null    object
#  3   Amount         319 non-null    int64
#  4   Location       319 non-null    object
#  5   About Company  319 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 17.4+ KB
